# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

working_directory = '/home/talentum/spark/jars/*'

# %% [markdown]
# Here we are creating Spark connection to mongoDB.

# %%
# enter id and password of atlas account in field
database="new"
collection="corparate_credit_rating_datset"
connectionstring="mongodb+srv://<id>:<password>@cluster0.5xyb5sn.mongodb.net/?retryWrites=true&w=majority"

# %%
spark =SparkSession.builder.config('spark.mongodb.input.uri',connectionstring).config('spark.mongodb.output.uri',connectionstring).config('spark.jars.packages','org.mongodb.spark:mongo-spark-connector_2.11-2.4.4').getOrCreate()

# %%
df = spark.read.format("com.mongodb.spark.sql.DefaultSource").option("uri",connectionstring).option('database',database).option('collection',collection).load()

# %% [markdown]
# Exploratory Data Analysis
# Our first step is to perform an exploratory data analysis to understand the charateristics of dataset. Here are some quesitons we will try to adress:
#
# What are the dimensions of the data?
#
# How do predictors relate to each other?
#
# What are the classes of the data?
#
# How are the predictors distributed?
#
# How are the labels distributed?
#
# Do we have missing values?
#
# Are outliers are relevant?
#
# Are there any transformations that must be
# done with the dataset?

# %%
df.summary().show(vertical=True)
# Out:
# -RECORD 0--------------------------------------------------
#  summary                            | count
#  Clean_Name                         | 2034
#  Rating                             | 2034
#  Rating Agency Name                 | 2034
#  Sector                             | 2034
#  Symbol                             | 2034
#  Year                               | 2034
#  assetTurnover                      | 2034
#  cashFlowToDebtRatio                | 2034
#  cashPerShare                       | 2034
#  cashRatio                          | 2034
#  currentRatio                       | 2034
#  daysOfSalesOutstanding             | 2034
#  debtRatio                          | 2034
#  ebitPerRevenue                     | 2034
#  effectiveTaxRate                   | 2034
#  enterpriseValueMultiple            | 2034
#  freeCashFlowOperatingCashFlowRatio | 2034
#  freeCashFlowPerShare               | 2034
#  grossProfitMargin                  | 2034
#  interestCoverage                   | 2034
#  netProfitMargin                    | 2034
#  operatingCashFlowPerShare          | 2034
#  operatingCashFlowSalesRatio        | 2034
#  operatingProfitMargin              | 2034
#  payoutRatio                        | 2034
#  pretaxProfitMargin                 | 2034
#  priceEarningsToGrowthRatio         | 2034
#  quickRatio                         | 2034
#  returnOnAssets                     | 2034
#  returnOnCapitalEmployed            | 2034
# -RECORD 1--------------------------------------------------
#  summary                            | mean
#  Clean_Name                         | null
#  Rating                             | null
#  Rating Agency Name                 | null
#  Sector                             | NaN
#  Symbol                             | null
#  Year                               | 2018.9891838741396
#  assetTurnover                      | 1.3101736290662955
#  cashFlowToDebtRatio                | 0.7344992643174538
#  cashPerShare                       | 122.02873870859068
#  cashRatio                          | 0.6485497317803354
#  currentRatio                       | 1.9115327772521686
#  daysOfSalesOutstanding             | 84877.39709883943
#  debtRatio                          | 0.7262753906006937
#  ebitPerRevenue                     | 0.08219096069920535
#  effectiveTaxRate                   | 0.14259271498893428
#  enterpriseValueMultiple            | 13.741571042118549
#  freeCashFlowOperatingCashFlowRatio | 1.0847309992621132
#  freeCashFlowPerShare               | 37.94777374869553
#  grossProfitMargin                  | -147.29241315896545
#  interestCoverage                   | -0.6825492702844173
#  netProfitMargin                    | 0.04905933181544663
#  operatingCashFlowPerShare          | 114.8857099378501
#  operatingCashFlowSalesRatio        | 269.04759849956656
#  operatingProfitMargin              | 0.08219096069920535
#  payoutRatio                        | 0.45297493670859756
#  pretaxProfitMargin                 | 0.0621209934797514
#  priceEarningsToGrowthRatio         | -354.953555099417
#  quickRatio                         | 25.947627728476178
#  returnOnAssets                     | 0.060101820302839455
#  returnOnCapitalEmployed            | 0.1419078659734163
# -RECORD 2--------------------------------------------------
#  summary                            | stddev
#  Clean_Name                         | null
#  Rating                             | null
#  Rating Agency Name                 | null
#  Sector                             | NaN
#  Symbol                             | null
#  Year                               | 1.2984841222954775
#  assetTurnover                      | 27.2215650068025
#  cashFlowToDebtRatio                | 9.519432295177483
#  cashPerShare                       | 1750.1742225516543
#  cashRatio                          | 4.282315982992534
#  currentRatio                       | 7.754033748954608
#  daysOfSalesOutstanding             | 3825340.2039795797
#  debtRatio                          | 1.3058025722519746
#  ebitPerRevenue                     | 1.1386792781474626
#  effectiveTaxRate                   | 2.8357122477693104
#  enterpriseValueMultiple            | 106.36718590906354
#  freeCashFlowOperatingCashFlowRatio | 26.0518401774412
#  freeCashFlowPerShare               | 612.3560213446431
#  grossProfitMargin                  | 6659.481323416307
#  interestCoverage                   | 376.34138546516783
#  netProfitMargin                    | 0.4564938249384967
#  operatingCashFlowPerShare          | 1195.438292990533
#  operatingCashFlowSalesRatio        | 12125.381760818946
#  operatingProfitMargin              | 1.1386792781474626
#  payoutRatio                        | 3.4204645231252013
#  pretaxProfitMargin                 | 0.4680972691623854
#  priceEarningsToGrowthRatio         | 15997.600417483627
#  quickRatio                         | 1102.7306783089725
#  returnOnAssets                     | 1.2333396675408352
#  returnOnCapitalEmployed            | 2.5071527094659447
# -RECORD 3--------------------------------------------------
#  summary                            | min
#  Clean_Name                         | 1 automotive
#  Rating                             | A
#  Rating Agency Name                 | DBRS
#  Sector                             | Basic Industries
#  Symbol                             | AA
#  Year                               | 2015
#  assetTurnover                      | 2.470976353083988E-7
#  cashFlowToDebtRatio                | -4.269230769230769
#  cashPerShare                       | 0.0
#  cashRatio                          | 0.0
#  currentRatio                       | 0.0
#  daysOfSalesOutstanding             | 0.0
#  debtRatio                          | -0.1837221550949592
#  ebitPerRevenue                     | -49.60526315789474
#  effectiveTaxRate                   | -83.0
#  enterpriseValueMultiple            | -1902.7637178679456
#  freeCashFlowOperatingCashFlowRatio | -110.91666666666669
#  freeCashFlowPerShare               | -4685.898491482102
#  grossProfitMargin                  | -300341.5009099139
#  interestCoverage                   | -16911.0
#  netProfitMargin                    | -4.979559748427673
#  operatingCashFlowPerShare          | -32.376046503384515
#  operatingCashFlowSalesRatio        | -2.1535639412997902
#  operatingProfitMargin              | -49.60526315789474
#  payoutRatio                        | -42.37300411522634
#  pretaxProfitMargin                 | -4.990566037735849
#  priceEarningsToGrowthRatio         | -721489.9359691828
#  quickRatio                         | 0.0201188843164151
#  returnOnAssets                     | -1.7092064656603847
#  returnOnCapitalEmployed            | -2.6806947496047435
# -RECORD 4--------------------------------------------------
#  summary                            | 25%
#  Clean_Name                         | null
#  Rating                             | null
#  Rating Agency Name                 | null
#  Sector                             | NaN
#  Symbol                             | null
#  Year                               | 2018
#  assetTurnover                      | 0.3269364757431949
#  cashFlowToDebtRatio                | 0.1359066356503568
#  cashPerShare                       | 1.00095
#  cashRatio                          | 0.1166285087269676
#  currentRatio                       | 0.9286359216557856
#  daysOfSalesOutstanding             | 34.5624581481707
#  debtRatio                          | 0.5445620043396621
#  ebitPerRevenue                     | 0.0452636956007126
#  effectiveTaxRate                   | 0.022509153586472
#  enterpriseValueMultiple            | 7.099325173852573
#  freeCashFlowOperatingCashFlowRatio | 0.2418552107691335
#  freeCashFlowPerShare               | 0.3067511175962155
#  grossProfitMargin                  | 0.1997064232299747
#  interestCoverage                   | 1.5225390984360625
#  netProfitMargin                    | 0.0081991843506171
#  operatingCashFlowPerShare          | 2.3445840022665028
#  operatingCashFlowSalesRatio        | 0.0856849745058108
#  operatingProfitMargin              | 0.0452636956007126
#  payoutRatio                        | 0.0
#  pretaxProfitMargin                 | 0.0170937318938398
#  priceEarningsToGrowthRatio         | -0.4416089565968134
#  quickRatio                         | 0.5641577632488173
#  returnOnAssets                     | 0.0062581281114617
#  returnOnCapitalEmployed            | 0.0349200961753566
# -RECORD 5--------------------------------------------------
#  summary                            | 50%
#  Clean_Name                         | null
#  Rating                             | null
#  Rating Agency Name                 | null
#  Sector                             | NaN
#  Symbol                             | null
#  Year                               | 2019
#  assetTurnover                      | 0.5594244604316547
#  cashFlowToDebtRatio                | 0.2395220374835272
#  cashPerShare                       | 2.9989376176541853
#  cashRatio                          | 0.2801952876247081
#  currentRatio                       | 1.3528379902267886
#  daysOfSalesOutstanding             | 52.31603034242
#  debtRatio                          | 0.6594043022614451
#  ebitPerRevenue                     | 0.1154448621553884
#  effectiveTaxRate                   | 0.1847133757961783
#  enterpriseValueMultiple            | 11.022310407185628
#  freeCashFlowOperatingCashFlowRatio | 0.6072220024290983
#  freeCashFlowPerShare               | 2.0349726775956283
#  grossProfitMargin                  | 0.3372724243273772
#  interestCoverage                   | 3.6953125
#  netProfitMargin                    | 0.0651127005090213
#  operatingCashFlowPerShare          | 4.710465734018063
#  operatingCashFlowSalesRatio        | 0.1567980552179197
#  operatingProfitMargin              | 0.1154448621553884
#  payoutRatio                        | 0.2257432786269724
#  pretaxProfitMargin                 | 0.0809962116106378
#  priceEarningsToGrowthRatio         | 0.0441486068111455
#  quickRatio                         | 0.8976146220570013
#  returnOnAssets                     | 0.0364887250886151
#  returnOnCapitalEmployed            | 0.0755024153300061
# -RECORD 6--------------------------------------------------
#  summary                            | 75%
#  Clean_Name                         | null
#  Rating                             | null
#  Rating Agency Name                 | null
#  Sector                             | NaN
#  Symbol                             | null
#  Year                               | 2020
#  assetTurnover                      | 0.8910176660860911
#  cashFlowToDebtRatio                | 0.3835453774385072
#  cashPerShare                       | 7.48334312212312
#  cashRatio                          | 0.5990583494387105
#  currentRatio                       | 1.9341402634389464
#  daysOfSalesOutstanding             | 70.86192129267236
#  debtRatio                          | 0.7865314561917521
#  ebitPerRevenue                     | 0.190757499581029
#  effectiveTaxRate                   | 0.2605026929982046
#  enterpriseValueMultiple            | 16.164525245572296
#  freeCashFlowOperatingCashFlowRatio | 0.8106227106227106
#  freeCashFlowPerShare               | 4.852787326259154
#  grossProfitMargin                  | 0.5269119574664758
#  interestCoverage                   | 7.595238095238095
#  netProfitMargin                    | 0.1301419711416758
#  operatingCashFlowPerShare          | 8.444040036396725
#  operatingCashFlowSalesRatio        | 0.2785662909198326
#  operatingProfitMargin              | 0.190757499581029
#  payoutRatio                        | 0.5431931252826775
#  pretaxProfitMargin                 | 0.1556172436316133
#  priceEarningsToGrowthRatio         | 0.3954188969360689
#  quickRatio                         | 1.3347957156689525
#  returnOnAssets                     | 0.0730334328650448
#  returnOnCapitalEmployed            | 0.1296809236577724
# -RECORD 7--------------------------------------------------
#  summary                            | max
#  Clean_Name                         | zoetis
#  Rating                             | D
#  Rating Agency Name                 | Standard & Poor's...
#  Sector                             | Transportation
#  Symbol                             | ZTS
#  Year                               | 2021
#  assetTurnover                      | 1228.117999169867
#  cashFlowToDebtRatio                | 292.47740312472416
#  cashPerShare                       | 51491.9231642122
#  cashRatio                          | 165.35555555555555
#  currentRatio                       | 335.6464778233321
#  daysOfSalesOutstanding             | 1.725224772054912E8
#  debtRatio                          | 57.85471114082659
#  ebitPerRevenue                     | 2.628261504101535
#  effectiveTaxRate                   | 67.86462093862816
#  enterpriseValueMultiple            | 2144.635648013
#  freeCashFlowOperatingCashFlowRatio | 1143.846625766871
#  freeCashFlowPerShare               | 16324.809663902182
#  grossProfitMargin                  | 1.0161781606075786
#  interestCoverage                   | 970.0
#  netProfitMargin                    | 13.40901422913305
#  operatingCashFlowPerShare          | 27330.16649782924
#  operatingCashFlowSalesRatio        | 546853.5645292245
#  operatingProfitMargin              | 2.628261504101535
#  payoutRatio                        | 76.66666666666667
#  pretaxProfitMargin                 | 13.40901422913305
#  priceEarningsToGrowthRatio         | 139.64764908586957
#  quickRatio                         | 49732.65185185185
#  returnOnAssets                     | 55.36650007813821
#  returnOnCapitalEmployed            | 112.83524653091048

# %%
df.show(3,truncate=False, vertical=True)
# Out:
# -RECORD 0----------------------------------------------------------------
#  Clean_Name                         | southwest gas
#  Rating                             | AA
#  Rating Agency Name                 | Standard & Poor's Ratings Services
#  Sector                             | Public Utilities
#  Symbol                             | SWX
#  Year                               | 2021
#  _id                                | [632cde55fe2e7730e707bcd5]
#  assetTurnover                      | 0.2883178145179529
#  cashFlowToDebtRatio                | 0.0176182946937112
#  cashPerShare                       | 3.9768741740776457
#  cashRatio                          | 0.0715596059059481
#  currentRatio                       | 0.5188758274692976
#  daysOfSalesOutstanding             | 80.21508641196418
#  debtRatio                          | 0.7686047370609146
#  ebitPerRevenue                     | 0.1004061730478139
#  effectiveTaxRate                   | 0.1606157585578286
#  enterpriseValueMultiple            | 13.53227835974303
#  freeCashFlowOperatingCashFlowRatio | -5.424912239749333
#  freeCashFlowPerShare               | -10.79043894424801
#  grossProfitMargin                  | 0.2230517401264138
#  interestCoverage                   | 3.100219802345677
#  netProfitMargin                    | 0.0545528251836527
#  operatingCashFlowPerShare          | 1.9890531804707312
#  operatingCashFlowSalesRatio        | 0.0302634106526618
#  operatingProfitMargin              | 0.1004061730478139
#  payoutRatio                        | 0.6884285707170571
#  pretaxProfitMargin                 | 0.0670705845560775
#  priceEarningsToGrowthRatio         | -1.398241216977728
#  quickRatio                         | 0.3314665032587854
#  returnOnAssets                     | 0.0157285513327307
#  returnOnCapitalEmployed            | 0.0382815743740319
# -RECORD 1----------------------------------------------------------------
#  Clean_Name                         | southwest gas
#  Rating                             | AA
#  Rating Agency Name                 | Standard & Poor's Ratings Services
#  Sector                             | Public Utilities
#  Symbol                             | SWX
#  Year                               | 2020
#  _id                                | [632cde55fe2e7730e707bcd6]
#  assetTurnover                      | 2.712449545591709
#  cashFlowToDebtRatio                | 0.217416594406301
#  cashPerShare                       | 1.4884817314904104
#  cashRatio                          | 0.0913980440081713
#  currentRatio                       | 0.9550926733094508
#  daysOfSalesOutstanding             | 57.77511895729239
#  debtRatio                          | 7.182925956896786
#  ebitPerRevenue                     | 0.1282268217054733
#  effectiveTaxRate                   | 0.215768955627457
#  enterpriseValueMultiple            | 8.224506349550012
#  freeCashFlowOperatingCashFlowRatio | 1.0
#  freeCashFlowPerShare               | 11.180399299975
#  grossProfitMargin                  | 0.8960745078698089
#  interestCoverage                   | 3.7945405778770502
#  netProfitMargin                    | 0.0724444378428633
#  operatingCashFlowPerShare          | 11.180399299975
#  operatingCashFlowSalesRatio        | 0.1897860269249528
#  operatingProfitMargin              | 0.1282268217054733
#  payoutRatio                        | 0.5251542983869281
#  pretaxProfitMargin                 | 0.0923763964238696
#  priceEarningsToGrowthRatio         | 2.635969764031808
#  quickRatio                         | 0.6639757798253665
#  returnOnAssets                     | 0.1965018825075214
#  returnOnCapitalEmployed            | 1.3904085724616244
# -RECORD 2----------------------------------------------------------------
#  Clean_Name                         | southwest gas
#  Rating                             | AA
#  Rating Agency Name                 | Standard & Poor's Ratings Services
#  Sector                             | Public Utilities
#  Symbol                             | SWX
#  Year                               | 2019
#  _id                                | [632cde55fe2e7730e707bcd7]
#  assetTurnover                      | 0.3818725422421019
#  cashFlowToDebtRatio                | 0.1870553728344811
#  cashPerShare                       | 0.9132454604110978
#  cashRatio                          | 0.04587534877174
#  currentRatio                       | 0.7962654452749012
#  daysOfSalesOutstanding             | 68.43323716624514
#  debtRatio                          | 0.6932803821960409
#  ebitPerRevenue                     | 0.1191733626247108
#  effectiveTaxRate                   | 0.2054608134374885
#  enterpriseValueMultiple            | 9.939292402648215
#  freeCashFlowOperatingCashFlowRatio | -0.8749010736012407
#  freeCashFlowPerShare               | -8.070347497465205
#  grossProfitMargin                  | 0.2363447489147948
#  interestCoverage                   | 3.404052148755791
#  netProfitMargin                    | 0.0685710549351152
#  operatingCashFlowPerShare          | 9.224297170246103
#  operatingCashFlowSalesRatio        | 0.1603799075424122
#  operatingProfitMargin              | 0.1191733626247108
#  payoutRatio                        | 0.5428118689701593
#  pretaxProfitMargin                 | 0.0873965557417072
#  priceEarningsToGrowthRatio         | 2.8682545793134397
#  quickRatio                         | 0.5875635845724588
#  returnOnAssets                     | 0.0261854030722952
#  returnOnCapitalEmployed            | 0.0524402247782745
# only showing top 3 rows

# %%
from pyspark.sql.functions import isnan, when, count, col

df = df.select([c for c in df.columns if c not in ['_id']] )

# %%
'_id' in df.columns
# Out:
# False

# %% [markdown]
# Analyse Labels
#
# As we know we are working with ordinal labels. That means there is a scale from more secure to less secure ratings. For instance, the triple-A (AAA) is the most secure rating a company can receive. On the other hand, the rating D is the less secure. It means the company will likely default on its creditors. Let's have a first look at the how many reatings we have of each in the dataset.

# %%
df.groupby(col('Rating')).count().show()
# Out:
# +------+-----+
# |Rating|count|
# +------+-----+
# |    AA|   82|
# |   CCC|   75|
# |   BBB|  699|
# |     B|  289|
# |     D|    2|
# |     C|    8|
# |     A|  380|
# |    CC|    2|
# |   AAA|    6|
# |    BB|  491|
# +------+-----+

# %% [markdown]
# We observe that the dataset is very unbalanced. We have 699 triple-Bs (BBB) but only 2 D. However, we are working with Ratings from different companies such as Moody's, Standard & Poor's and more. Therefore it is preferred to simplify the labels according to this table from the website investopedia. We will classify our labels according to the grading risk and not the rate.

# %% [markdown]
# To do it we will replace with a dictonary each of this ratings.

# %%
from pyspark.sql.functions import when

df1 = df.withColumn("Rating desc", \
                when(df["Rating"] == 'AAA', 'Lowest Risk')\
                .when(df.Rating== 'AA','Low Risk')\
                .when(df.Rating== 'A','Low Risk')\
                .when(df.Rating== 'BBB','Medium Risk')\
                .when(df.Rating== 'BB','High Risk')\
                .when(df.Rating== 'B','High Risk')\
                .when(df.Rating== 'CCC','Highest Risk')\
                .when(df.Rating== 'CC','Highest Risk')\
                .when(df.Rating== 'C','Highest Risk')\
                .when(df.Rating== 'D','In Default'))

# %%
df1.groupby(col('Rating desc')).count().show()
# Out:
# +------------+-----+
# | Rating desc|count|
# +------------+-----+
# |    Low Risk|  462|
# |Highest Risk|   85|
# |  In Default|    2|
# | Lowest Risk|    6|
# | Medium Risk|  699|
# |   High Risk|  780|
# +------------+-----+

# %%
aa= (df1.groupby(col('Rating desc')).count()).toPandas()
aa.head()
import matplotlib.pyplot as plt
plt.bar(aa['Rating desc'],aa['count'])
plt.xticks(rotation=90)
plt.xlabel('Count of Rating by Type')
plt.grid()
plt.show()

# %% [markdown]
# Unfortunately, given the lack of Credit Ratings classified as Lowest Risk and In Default we will have to eliminate then from the table. However, the dataset will keep unbalanced and if needed we will have to adress this issue in further steps.

# %%
df1.count()
# Out:
# 2034

# %%
df2 = df1.filter(~df1['Rating desc'].isin(["Lowest Risk",'In Default']))
df2.count()
# Out:
# 2026

# %%
df3 = df2

# %%
from pyspark.sql.types import DoubleType
for i in df3.columns[0:6]:
    df3.withColumn(i, df2[i])

for i in df3.columns[-1:]:
    df3.withColumn(i, df2[i])
    
for i in df3.columns[6:-1]:
    df3.withColumn(i,col(i).cast(DoubleType()))

# %%
df3.printSchema()
# Out:
# root
#  |-- Clean_Name: string (nullable = true)
#  |-- Rating: string (nullable = true)
#  |-- Rating Agency Name: string (nullable = true)
#  |-- Sector: string (nullable = true)
#  |-- Symbol: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- assetTurnover: double (nullable = true)
#  |-- cashFlowToDebtRatio: double (nullable = true)
#  |-- cashPerShare: double (nullable = true)
#  |-- cashRatio: double (nullable = true)
#  |-- currentRatio: double (nullable = true)
#  |-- daysOfSalesOutstanding: double (nullable = true)
#  |-- debtRatio: double (nullable = true)
#  |-- ebitPerRevenue: double (nullable = true)
#  |-- effectiveTaxRate: double (nullable = true)
#  |-- enterpriseValueMultiple: double (nullable = true)
#  |-- freeCashFlowOperatingCashFlowRatio: double (nullable = true)
#  |-- freeCashFlowPerShare: double (nullable = true)
#  |-- grossProfitMargin: double (nullable = true)
#  |-- interestCoverage: double (nullable = true)
#  |-- netProfitMargin: double (nullable = true)
#  |-- operatingCashFlowPerShare: double (nullable = true)
#  |-- operatingCashFlowSalesRatio: double (nullable = true)
#  |-- operatingProfitMargin: double (nullable = true)
#  |-- payoutRatio: double (nullable = true)
#  |-- pretaxProfitMargin: double (nullable = true)
#  |-- priceEarningsToGrowthRatio: double (nullable = true)
#  |-- quickRatio: double (nullable = true)
#  |-- returnOnAssets: double (nullable = true)
#  |-- returnOnCapitalEmployed: double (nullable = true)
#  |-- Rating desc: string (nullable = true)

# %% [markdown]
# Descriptive Statistics
#
# Now we will use statistical tools, especially from pandas to improve the understanding from the dataset, especially the numerical features. We have seen there are 25 numerical columns in the dataset, all of each are financial indicators from the companies. The function describe() returns information about the distribution of the data such as mean, min and max.

# %%
for i in df3.columns[6:-1]:
    print(f'Column Name : {i}')
    df3.describe(i).show()
    print()
# Out:
# Column Name : assetTurnover
# +-------+--------------------+
# |summary|       assetTurnover|
# +-------+--------------------+
# |  count|                2026|
# |   mean|   1.313863536131195|
# | stddev|  27.275217857912907|
# |    min|2.470976353083988E-7|
# |    max|   1228.117999169867|
# +-------+--------------------+
#
#
# Column Name : cashFlowToDebtRatio
# +-------+-------------------+
# |summary|cashFlowToDebtRatio|
# +-------+-------------------+
# |  count|               2026|
# |   mean| 0.7350468896421631|
# | stddev|  9.538109802705693|
# |    min| -4.269230769230769|
# |    max| 292.47740312472416|
# +-------+-------------------+
#
#
# Column Name : cashPerShare
# +-------+------------------+
# |summary|      cashPerShare|
# +-------+------------------+
# |  count|              2026|
# |   mean|117.30865540696759|
# | stddev|1746.3896863471987|
# |    min|               0.0|
# |    max|  51491.9231642122|
# +-------+------------------+
#
#
# Column Name : cashRatio
# +-------+------------------+
# |summary|         cashRatio|
# +-------+------------------+
# |  count|              2026|
# |   mean| 0.650525251871495|
# | stddev|4.2906459455813355|
# |    min|               0.0|
# |    max|165.35555555555555|
# +-------+------------------+
#
#
# Column Name : currentRatio
# +-------+------------------+
# |summary|      currentRatio|
# +-------+------------------+
# |  count|              2026|
# |   mean|1.9147768013532216|
# | stddev| 7.769026080008029|
# |    min|               0.0|
# |    max| 335.6464778233321|
# +-------+------------------+
#
#
# Column Name : daysOfSalesOutstanding
# +-------+----------------------+
# |summary|daysOfSalesOutstanding|
# +-------+----------------------+
# |  count|                  2026|
# |   mean|     85212.31466729793|
# | stddev|     3832885.261145928|
# |    min|                   0.0|
# |    max|   1.725224772054912E8|
# +-------+----------------------+
#
#
# Column Name : debtRatio
# +-------+-------------------+
# |summary|          debtRatio|
# +-------+-------------------+
# |  count|               2026|
# |   mean| 0.7253468462720805|
# | stddev| 1.3080811703550608|
# |    min|-0.1837221550949592|
# |    max|  57.85471114082659|
# +-------+-------------------+
#
#
# Column Name : ebitPerRevenue
# +-------+-------------------+
# |summary|     ebitPerRevenue|
# +-------+-------------------+
# |  count|               2026|
# |   mean|0.08178697919530113|
# | stddev|  1.140849973727097|
# |    min| -49.60526315789474|
# |    max|  2.628261504101535|
# +-------+-------------------+
#
#
# Column Name : effectiveTaxRate
# +-------+------------------+
# |summary|  effectiveTaxRate|
# +-------+------------------+
# |  count|              2026|
# |   mean|0.1433737506605455|
# | stddev|2.8412330233367875|
# |    min|             -83.0|
# |    max| 67.86462093862816|
# +-------+------------------+
#
#
# Column Name : enterpriseValueMultiple
# +-------+-----------------------+
# |summary|enterpriseValueMultiple|
# +-------+-----------------------+
# |  count|                   2026|
# |   mean|     13.762747433600122|
# | stddev|     106.57438168919751|
# |    min|    -1902.7637178679456|
# |    max|         2144.635648013|
# +-------+-----------------------+
#
#
# Column Name : freeCashFlowOperatingCashFlowRatio
# +-------+----------------------------------+
# |summary|freeCashFlowOperatingCashFlowRatio|
# +-------+----------------------------------+
# |  count|                              2026|
# |   mean|                1.0878025076410145|
# | stddev|                  26.1031356460555|
# |    min|               -110.91666666666669|
# |    max|                 1143.846625766871|
# +-------+----------------------------------+
#
#
# Column Name : freeCashFlowPerShare
# +-------+--------------------+
# |summary|freeCashFlowPerShare|
# +-------+--------------------+
# |  count|                2026|
# |   mean|  33.805855048568354|
# | stddev|   602.8354499884362|
# |    min|  -4685.898491482102|
# |    max|  16324.809663902182|
# +-------+--------------------+
#
#
# Column Name : grossProfitMargin
# +-------+-------------------+
# |summary|  grossProfitMargin|
# +-------+-------------------+
# |  count|               2026|
# |   mean|-147.87656640472224|
# | stddev|  6672.616383548726|
# |    min| -300341.5009099139|
# |    max| 1.0161781606075786|
# +-------+-------------------+
#
#
# Column Name : interestCoverage
# +-------+-------------------+
# |summary|   interestCoverage|
# +-------+-------------------+
# |  count|               2026|
# |   mean|-0.7079088870280054|
# | stddev|  377.0831036817682|
# |    min|           -16911.0|
# |    max|              970.0|
# +-------+-------------------+
#
#
# Column Name : netProfitMargin
# +-------+-------------------+
# |summary|    netProfitMargin|
# +-------+-------------------+
# |  count|               2026|
# |   mean|0.04890135810130282|
# | stddev| 0.4572199999182179|
# |    min| -4.979559748427673|
# |    max|  13.40901422913305|
# +-------+-------------------+
#
#
# Column Name : operatingCashFlowPerShare
# +-------+-------------------------+
# |summary|operatingCashFlowPerShare|
# +-------+-------------------------+
# |  count|                     2026|
# |   mean|       105.05168436185554|
# | stddev|       1170.5627967975888|
# |    min|      -32.376046503384515|
# |    max|        27330.16649782924|
# +-------+-------------------------+
#
#
# Column Name : operatingCashFlowSalesRatio
# +-------+---------------------------+
# |summary|operatingCashFlowSalesRatio|
# +-------+---------------------------+
# |  count|                       2026|
# |   mean|          270.1089929039576|
# | stddev|         12149.297729498863|
# |    min|        -2.1535639412997902|
# |    max|          546853.5645292245|
# +-------+---------------------------+
#
#
# Column Name : operatingProfitMargin
# +-------+---------------------+
# |summary|operatingProfitMargin|
# +-------+---------------------+
# |  count|                 2026|
# |   mean|  0.08178697919530113|
# | stddev|    1.140849973727097|
# |    min|   -49.60526315789474|
# |    max|    2.628261504101535|
# +-------+---------------------+
#
#
# Column Name : payoutRatio
# +-------+-------------------+
# |summary|        payoutRatio|
# +-------+-------------------+
# |  count|               2026|
# |   mean|0.45446176874887884|
# | stddev| 3.4271220051404754|
# |    min| -42.37300411522634|
# |    max|  76.66666666666667|
# +-------+-------------------+
#
#
# Column Name : pretaxProfitMargin
# +-------+-------------------+
# |summary| pretaxProfitMargin|
# +-------+-------------------+
# |  count|               2026|
# |   mean|0.06189151938262066|
# | stddev|0.46885688793651936|
# |    min| -4.990566037735849|
# |    max|  13.40901422913305|
# +-------+-------------------+
#
#
# Column Name : priceEarningsToGrowthRatio
# +-------+--------------------------+
# |summary|priceEarningsToGrowthRatio|
# +-------+--------------------------+
# |  count|                      2026|
# |   mean|        -356.3567881454673|
# | stddev|        16029.153843105405|
# |    min|        -721489.9359691828|
# |    max|        139.64764908586957|
# +-------+--------------------------+
#
#
# Column Name : quickRatio
# +-------+------------------+
# |summary|        quickRatio|
# +-------+------------------+
# |  count|              2026|
# |   mean|26.046435127724358|
# | stddev|  1104.90563984926|
# |    min|0.0201188843164151|
# |    max| 49732.65185185185|
# +-------+------------------+
#
#
# Column Name : returnOnAssets
# +-------+-------------------+
# |summary|     returnOnAssets|
# +-------+-------------------+
# |  count|               2026|
# |   mean|0.06023961588895527|
# | stddev| 1.2357533134680545|
# |    min|-1.7092064656603847|
# |    max|  55.36650007813821|
# +-------+-------------------+
#
#
# Column Name : returnOnCapitalEmployed
# +-------+-----------------------+
# |summary|returnOnCapitalEmployed|
# +-------+-----------------------+
# |  count|                   2026|
# |   mean|     0.1419556490928027|
# | stddev|       2.51207614832533|
# |    min|    -2.6806947496047435|
# |    max|     112.83524653091048|
# +-------+-----------------------+

# %%
df3.describe().toPandas().transpose()
# Out:
#                                         0                    1  \
# summary                             count                 mean
# Clean_Name                           2026                 None
# Rating                               2026                 None
# Rating Agency Name                   2026                 None
# Sector                               2026                  NaN
# Symbol                               2026                 None
# Year                                 2026   2018.9881539980256
# assetTurnover                        2026    1.313863536131195
# cashFlowToDebtRatio                  2026   0.7350468896421631
# cashPerShare                         2026   117.30865540696759
# cashRatio                            2026    0.650525251871495
# currentRatio                         2026   1.9147768013532216
# daysOfSalesOutstanding               2026    85212.31466729793
# debtRatio                            2026   0.7253468462720805
# ebitPerRevenue                       2026  0.08178697919530113
# effectiveTaxRate                     2026   0.1433737506605455
# enterpriseValueMultiple              2026   13.762747433600122
# freeCashFlowOperatingCashFlowRatio   2026   1.0878025076410145
# freeCashFlowPerShare                 2026   33.805855048568354
# grossProfitMargin                    2026  -147.87656640472224
# interestCoverage                     2026  -0.7079088870280054
# netProfitMargin                      2026  0.04890135810130282
# operatingCashFlowPerShare            2026   105.05168436185554
# operatingCashFlowSalesRatio          2026    270.1089929039576
# operatingProfitMargin                2026  0.08178697919530113
# payoutRatio                          2026  0.45446176874887884
# pretaxProfitMargin                   2026  0.06189151938262066
# priceEarningsToGrowthRatio           2026   -356.3567881454673
# quickRatio                           2026   26.046435127724358
# returnOnAssets                       2026  0.06023961588895527
# returnOnCapitalEmployed              2026   0.1419556490928027
# Rating desc                          2026                 None
#
#                                                       2                     3  \
# summary                                          stddev                   min
# Clean_Name                                         None          1 automotive
# Rating                                             None                     A
# Rating Agency Name                                 None                  DBRS
# Sector                                              NaN      Basic Industries
# Symbol                                             None                    AA
# Year                                  1.298758323625264                  2015
# assetTurnover                        27.275217857912907  2.470976353083988E-7
# cashFlowToDebtRatio                   9.538109802705693    -4.269230769230769
# cashPerShare                         1746.3896863471987                   0.0
# cashRatio                            4.2906459455813355                   0.0
# currentRatio                          7.769026080008029                   0.0
# daysOfSalesOutstanding                3832885.261145928                   0.0
# debtRatio                            1.3080811703550608   -0.1837221550949592
# ebitPerRevenue                        1.140849973727097    -49.60526315789474
# effectiveTaxRate                     2.8412330233367875                 -83.0
# enterpriseValueMultiple              106.57438168919751   -1902.7637178679456
# freeCashFlowOperatingCashFlowRatio     26.1031356460555   -110.91666666666669
# freeCashFlowPerShare                  602.8354499884362    -4685.898491482102
# grossProfitMargin                     6672.616383548726    -300341.5009099139
# interestCoverage                      377.0831036817682              -16911.0
# netProfitMargin                      0.4572199999182179    -4.979559748427673
# operatingCashFlowPerShare            1170.5627967975888   -32.376046503384515
# operatingCashFlowSalesRatio          12149.297729498863   -2.1535639412997902
# operatingProfitMargin                 1.140849973727097    -49.60526315789474
# payoutRatio                          3.4271220051404754    -42.37300411522634
# pretaxProfitMargin                  0.46885688793651936    -4.990566037735849
# priceEarningsToGrowthRatio           16029.153843105405    -721489.9359691828
# quickRatio                             1104.90563984926    0.0201188843164151
# returnOnAssets                       1.2357533134680545   -1.7092064656603847
# returnOnCapitalEmployed                2.51207614832533   -2.6806947496047435
# Rating desc                                        None             High Risk
#
#                                                                      4
# summary                                                            max
# Clean_Name                                                      zoetis
# Rating                                                             CCC
# Rating Agency Name                  Standard & Poor's Ratings Services
# Sector                                                  Transportation
# Symbol                                                             ZTS
# Year                                                              2021
# assetTurnover                                        1228.117999169867
# cashFlowToDebtRatio                                 292.47740312472416
# cashPerShare                                          51491.9231642122
# cashRatio                                           165.35555555555555
# currentRatio                                         335.6464778233321
# daysOfSalesOutstanding                             1.725224772054912E8
# debtRatio                                            57.85471114082659
# ebitPerRevenue                                       2.628261504101535
# effectiveTaxRate                                     67.86462093862816
# enterpriseValueMultiple                                 2144.635648013
# freeCashFlowOperatingCashFlowRatio                   1143.846625766871
# freeCashFlowPerShare                                16324.809663902182
# grossProfitMargin                                   1.0161781606075786
# interestCoverage                                                 970.0
# netProfitMargin                                      13.40901422913305
# operatingCashFlowPerShare                            27330.16649782924
# operatingCashFlowSalesRatio                          546853.5645292245
# operatingProfitMargin                                2.628261504101535
# payoutRatio                                          76.66666666666667
# pretaxProfitMargin                                   13.40901422913305
# priceEarningsToGrowthRatio                          139.64764908586957
# quickRatio                                           49732.65185185185
# returnOnAssets                                       55.36650007813821
# returnOnCapitalEmployed                             112.83524653091048
# Rating desc                                                Medium Risk

# %%
from pyspark.sql.functions import skewness

for i in df3.columns[6:-1]:
    print(f'Column Name : {i}')
    df3.agg(skewness(i)).show()
    print()
# Out:
# Column Name : assetTurnover
# +-----------------------+
# |skewness(assetTurnover)|
# +-----------------------+
# |      44.94723935070655|
# +-----------------------+
#
#
# Column Name : cashFlowToDebtRatio
# +-----------------------------+
# |skewness(cashFlowToDebtRatio)|
# +-----------------------------+
# |           26.436361834213546|
# +-----------------------------+
#
#
# Column Name : cashPerShare
# +----------------------+
# |skewness(cashPerShare)|
# +----------------------+
# |      22.4708967256738|
# +----------------------+
#
#
# Column Name : cashRatio
# +-------------------+
# |skewness(cashRatio)|
# +-------------------+
# | 31.253195892006588|
# +-------------------+
#
#
# Column Name : currentRatio
# +----------------------+
# |skewness(currentRatio)|
# +----------------------+
# |     39.51230341770083|
# +----------------------+
#
#
# Column Name : daysOfSalesOutstanding
# +--------------------------------+
# |skewness(daysOfSalesOutstanding)|
# +--------------------------------+
# |               44.97777776725662|
# +--------------------------------+
#
#
# Column Name : debtRatio
# +-------------------+
# |skewness(debtRatio)|
# +-------------------+
# |  41.25427250994935|
# +-------------------+
#
#
# Column Name : ebitPerRevenue
# +------------------------+
# |skewness(ebitPerRevenue)|
# +------------------------+
# |     -40.917073713020194|
# +------------------------+
#
#
# Column Name : effectiveTaxRate
# +--------------------------+
# |skewness(effectiveTaxRate)|
# +--------------------------+
# |        -4.676826008646209|
# +--------------------------+
#
#
# Column Name : enterpriseValueMultiple
# +---------------------------------+
# |skewness(enterpriseValueMultiple)|
# +---------------------------------+
# |                6.195501486892425|
# +---------------------------------+
#
#
# Column Name : freeCashFlowOperatingCashFlowRatio
# +--------------------------------------------+
# |skewness(freeCashFlowOperatingCashFlowRatio)|
# +--------------------------------------------+
# |                           41.65711178721125|
# +--------------------------------------------+
#
#
# Column Name : freeCashFlowPerShare
# +------------------------------+
# |skewness(freeCashFlowPerShare)|
# +------------------------------+
# |             17.44555829592866|
# +------------------------------+
#
#
# Column Name : grossProfitMargin
# +---------------------------+
# |skewness(grossProfitMargin)|
# +---------------------------+
# |          -44.9777776958112|
# +---------------------------+
#
#
# Column Name : interestCoverage
# +--------------------------+
# |skewness(interestCoverage)|
# +--------------------------+
# |        -44.53751610418209|
# +--------------------------+
#
#
# Column Name : netProfitMargin
# +-------------------------+
# |skewness(netProfitMargin)|
# +-------------------------+
# |        9.858993528932935|
# +-------------------------+
#
#
# Column Name : operatingCashFlowPerShare
# +-----------------------------------+
# |skewness(operatingCashFlowPerShare)|
# +-----------------------------------+
# |                 14.811666467718556|
# +-----------------------------------+
#
#
# Column Name : operatingCashFlowSalesRatio
# +-------------------------------------+
# |skewness(operatingCashFlowSalesRatio)|
# +-------------------------------------+
# |                    44.97777776031274|
# +-------------------------------------+
#
#
# Column Name : operatingProfitMargin
# +-------------------------------+
# |skewness(operatingProfitMargin)|
# +-------------------------------+
# |            -40.917073713020194|
# +-------------------------------+
#
#
# Column Name : payoutRatio
# +---------------------+
# |skewness(payoutRatio)|
# +---------------------+
# |     9.56325755294429|
# +---------------------+
#
#
# Column Name : pretaxProfitMargin
# +----------------------------+
# |skewness(pretaxProfitMargin)|
# +----------------------------+
# |           8.891618917665594|
# +----------------------------+
#
#
# Column Name : priceEarningsToGrowthRatio
# +------------------------------------+
# |skewness(priceEarningsToGrowthRatio)|
# +------------------------------------+
# |                 -44.977720117154675|
# +------------------------------------+
#
#
# Column Name : quickRatio
# +--------------------+
# |skewness(quickRatio)|
# +--------------------+
# |  44.972700027717245|
# +--------------------+
#
#
# Column Name : returnOnAssets
# +------------------------+
# |skewness(returnOnAssets)|
# +------------------------+
# |       44.28209251283065|
# +------------------------+
#
#
# Column Name : returnOnCapitalEmployed
# +---------------------------------+
# |skewness(returnOnCapitalEmployed)|
# +---------------------------------+
# |                 44.5976312173783|
# +---------------------------------+

# %% [markdown]
# Skewness and Outliers
#
# We observe a lot of skewness in the data with this first exploration.
#
# To observe how this reflect on the distribution of the data lets make some plots of variables chose randomly.

# %%
df_rating = df3.toPandas()

# %%
from random import sample
column_list = list(df3.columns[6:-1])
column_list = sample(column_list,4) 
print(column_list)
# Out:
# ['returnOnCapitalEmployed', 'enterpriseValueMultiple', 'returnOnAssets', 'daysOfSalesOutstanding']

# %%
figure, axes = plt.subplots(nrows=2, ncols=4, figsize=(9,5))

axes[0, 0].hist(df_rating[column_list[0]])
axes[0, 1].hist(df_rating[column_list[1]])
axes[1, 0].hist(df_rating[column_list[2]])
axes[1, 1].hist(df_rating[column_list[3]])

axes[0, 2].boxplot(df_rating[column_list[0]])
axes[1, 2].boxplot(df_rating[column_list[1]])
axes[0, 3].boxplot(df_rating[column_list[2]])
axes[1, 3].boxplot(df_rating[column_list[3]])

figure.tight_layout()

# %% [markdown]
# As predicted, the data is comtaminated by outliers. We canot observe real behaviour of the distribution because some points differ too much from the others. We will use the function .skew from pandas in all columns. It should return between 0 and 1 if a column is normally distributed.

# %%
for c in df_rating.columns[6:-1]:

    q1 = df_rating[c].quantile(0.25)
    q3 = df_rating[c].quantile(0.75)
    iqr = q3 - q1 #Interquartile range
    fence_low  = q3-1.5*iqr
    fence_high = q1+1.5*iqr
    lower_out = len(df_rating.loc[(df_rating[c] < fence_low)  ,c])
    upper_out = len(df_rating.loc[(df_rating[c] > fence_high)  ,c])
    outlier_count = upper_out+lower_out
    prop_out = outlier_count/len(df_rating)
    print(c, ": "+"{:.2%}".format(prop_out))
# Out:
# assetTurnover : 15.35%
# cashFlowToDebtRatio : 21.17%
# cashPerShare : 15.89%
# cashRatio : 16.39%
# currentRatio : 18.31%
# daysOfSalesOutstanding : 22.51%
# debtRatio : 17.62%
# ebitPerRevenue : 23.20%
# effectiveTaxRate : 22.70%
# enterpriseValueMultiple : 23.74%
# freeCashFlowOperatingCashFlowRatio : 18.95%
# freeCashFlowPerShare : 24.83%
# grossProfitMargin : 13.23%
# interestCoverage : 22.70%
# netProfitMargin : 27.69%
# operatingCashFlowPerShare : 18.26%
# operatingCashFlowSalesRatio : 17.52%
# operatingProfitMargin : 23.20%
# payoutRatio : 19.50%
# pretaxProfitMargin : 27.30%
# priceEarningsToGrowthRatio : 34.11%
# quickRatio : 16.49%
# returnOnAssets : 25.42%
# returnOnCapitalEmployed : 23.74%

# %% [markdown]
# Most columns have a significant number of outliers. However it is not clear for us if there are a few rows that all outliers or each of the rows may be contributing individually with some outliers. We will now check by row the distribution of outliers. We will create a new dataframe that df_rating_outlier that will be used with this purpose. In this dataframe every cell will 1 one if the corresponding cell is an outlier in df_raint and 0 if it is not.

# %% [markdown]
# Now we will be able to count how many outliers each row has and plot it.

# %%
df_rating_outlier = df_rating.copy()

for c in df_rating_outlier.columns[5:30]:
    
    q1 = df_rating_outlier[c].quantile(0.25)
    q3 = df_rating_outlier[c].quantile(0.75)
    iqr = q3 - q1 #Interquartile range
    fence_low  = q3-1.5*iqr
    fence_high = q1+1.5*iqr
    
    for i in range(len(df_rating_outlier)):
        
        if df_rating.loc[i,c] < fence_low or df_rating.loc[i,c] > fence_high: # if Outlier
            
            df_rating_outlier.loc[i,c] = 1
        
        else: # Not Outlier
            df_rating_outlier.loc[i,c] = 0
            
df_rating_outlier["total"] = df_rating_outlier.sum(axis=1)
df_rating_outlier.total.hist(bins = 10)
plt.show()

# %% [markdown]
# This is a very interesting plot. We can see that up to 300 rows don't have any outliers. Most rows have outliers and maybe they will be useful in the further classification tasks. Therefore we see no value in excluding the outliers from the dataset.

# %%
df_rating_no_out = df_rating.copy()

for c in df_rating_no_out.columns[6:-1]:

    q05 = df_rating_no_out[c].quantile(0.10)
    q95 = df_rating_no_out[c].quantile(0.90)
    iqr = q95 - q05 #Interquartile range
    fence_low  = q05-1.5*iqr
    fence_high = q95+1.5*iqr
    df_rating_no_out.loc[df_rating_no_out[c] > fence_high,c] = df_rating_no_out[c].quantile(0.25)
    df_rating_no_out.loc[df_rating_no_out[c] < fence_low,c] = df_rating_no_out[c].quantile(0.75)

# %% [markdown]
# Now that we have this dataframe we can use it use it to observe the data from a different angle. We will be able to observe the distribution that was hidden by the outliers. The first step:
#
# Plot all columns (boxplot) by each label:High Risk, Low Risk, Medium Risk, Highest Risk.

# %%
figure, axes = plt.subplots(nrows=6, ncols=4, figsize=(20,44))

i = 0 
j = 0

for c in df_rating_no_out.columns[6:-1]:
    
    sns.boxplot(x=df_rating_no_out.Rating, y=df_rating_no_out[c], palette="Set3", ax=axes[i, j])
    
    if j == 3:
        j=0
        i+=1
    else:
        j+=1

# %% [markdown]
# The most interesting point about the previous plots is the fact that they clearly show a difference in the medians and distribution according to the rating (Risk). It points to a scenario where the variables will have good predictive power for classification. Following with our analysis we will create scatter plots to see if we can observe who the variables relate to each other and how labels can be observer in respect to it

# %%
column_list = list(df_rating.columns[6:-1])
column_list = sample(column_list,12)

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(14,14))

i = 0 
j = 0

for c in range(0,12, 2):

    sns.scatterplot(x = column_list[c], y=column_list[c+1], hue=df_rating_no_out.Rating, data=df_rating_no_out, ax=axes[j,i])
    
    if i == 1:
        i = 0
        j +=1
    
    else:
        i+=1

# %% [markdown]
# In fact, we are working with a dataset that has a big numer of dimensions. With two variables it would not be possible to make any predictions. However this is not the case. Unfortunately we are not able to vizualise the data in all its dimensions, but luckely we will be able to perform accurate classificaitons.

# %% [markdown]
# # **Machine Learning**

# %% [markdown]
# Is it possible to predict what creidt profile a company will receive from a rating agency based on its financial indicators? If so, what are the most important predictors? Apparently not much work has been done with regards to this question. This academic paper was the only work found about it. It is worth checking it out. As we will do it, it tests most ML algorithms and identifies the most important features.
#
# In the following steps we will perform the following:
#
# 1. Prepare the dataset
#
#     Split in train and test
#
#     Transform/Encode the features kand labels
#
# 2. Test a wide range of ML models (Tree-based, Probabilistic and so on).
#
# 3. Compare the accuracry of all models.
#
# 4. Choose our winning model and tune hyperparameters to target a higher
# accuracy.
#
# 5. Make a more profound evaluation of the result with a confusion matrix and different measures.
#
# 6. identify the most important features to predict the rating.

# %% [markdown]
# # Prepare the Dataset

# %%
import pandas as pd
import pymongo
import numpy as np
from numpy import loadtxt
from numpy import sort
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.ticker import PercentFormatter
import matplotlib.ticker as mtick
from wordcloud import WordCloud, STOPWORDS 
from random import sample
import seaborn as sns
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.utils import resample
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel
# Out:
# /home/talentum/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:119: PkgResourcesDeprecationWarning: 0.18ubuntu0.18.04.1 is an invalid version and will not be supported in a future release
#   PkgResourcesDeprecationWarning,

# %%
pd.set_option('display.max_columns', 500)
df_rating.head(3)
# Out:
#       Clean_Name Rating                  Rating Agency Name            Sector  \
# 0  southwest gas     AA  Standard & Poor's Ratings Services  Public Utilities
# 1  southwest gas     AA  Standard & Poor's Ratings Services  Public Utilities
# 2  southwest gas     AA  Standard & Poor's Ratings Services  Public Utilities
#
#   Symbol  Year  assetTurnover  cashFlowToDebtRatio  cashPerShare  cashRatio  \
# 0    SWX  2021       0.288318             0.017618      3.976874   0.071560
# 1    SWX  2020       2.712450             0.217417      1.488482   0.091398
# 2    SWX  2019       0.381873             0.187055      0.913245   0.045875
#
#    currentRatio  daysOfSalesOutstanding  debtRatio  ebitPerRevenue  \
# 0      0.518876               80.215086   0.768605        0.100406
# 1      0.955093               57.775119   7.182926        0.128227
# 2      0.796265               68.433237   0.693280        0.119173
#
#    effectiveTaxRate  enterpriseValueMultiple  \
# 0          0.160616                13.532278
# 1          0.215769                 8.224506
# 2          0.205461                 9.939292
#
#    freeCashFlowOperatingCashFlowRatio  freeCashFlowPerShare  \
# 0                           -5.424912            -10.790439
# 1                            1.000000             11.180399
# 2                           -0.874901             -8.070347
#
#    grossProfitMargin  interestCoverage  netProfitMargin  \
# 0           0.223052          3.100220         0.054553
# 1           0.896075          3.794541         0.072444
# 2           0.236345          3.404052         0.068571
#
#    operatingCashFlowPerShare  operatingCashFlowSalesRatio  \
# 0                   1.989053                     0.030263
# 1                  11.180399                     0.189786
# 2                   9.224297                     0.160380
#
#    operatingProfitMargin  payoutRatio  pretaxProfitMargin  \
# 0               0.100406     0.688429            0.067071
# 1               0.128227     0.525154            0.092376
# 2               0.119173     0.542812            0.087397
#
#    priceEarningsToGrowthRatio  quickRatio  returnOnAssets  \
# 0                   -1.398241    0.331467        0.015729
# 1                    2.635970    0.663976        0.196502
# 2                    2.868255    0.587564        0.026185
#
#    returnOnCapitalEmployed Rating desc
# 0                 0.038282    Low Risk
# 1                 1.390409    Low Risk
# 2                 0.052440    Low Risk

# %%
df_rating=df_rating.drop(['Rating'],axis=1)
df_rating['Rating']=df_rating['Rating desc']
df_rating=df_rating.drop(['Rating desc'],axis=1)

# %%
dfadds = df_rating.copy()

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_rating.Sector)
df_rating.Sector = le1.transform(df_rating.Sector) # encode sector

le2 = preprocessing.LabelEncoder()
le2.fit(df_rating['Rating'])
df_rating['Rating'] = le2.transform(df_rating['Rating']) # encode rating

# %%
df_rating= df_rating.dropna()

# %%
df_train, df_test = train_test_split(df_rating, test_size=0.2, random_state = 2022)

# %%
X_train = df_train.drop(['Clean_Name','Rating','Rating Agency Name','Symbol'], axis=1)
y_train = df_train.Rating
X_test  = df_test.drop(['Clean_Name','Rating','Rating Agency Name','Symbol'] , axis=1)
y_test  = df_test.Rating

# %%
X_train.head(5)
# Out:
#       Sector  Year  assetTurnover  cashFlowToDebtRatio  cashPerShare  \
# 1204       5  2017       0.104699             0.223377      0.786183
# 93        11  2018       0.362554             0.270894      2.566631
# 1480       0  2020       0.458066             1.254643      7.011871
# 1345      11  2017       0.396131             0.291585     24.069285
# 1796       0  2020       0.513761             0.100039      0.416667
#
#       cashRatio  currentRatio  daysOfSalesOutstanding  debtRatio  \
# 1204   0.119551      0.943857               85.639321   0.376254
# 93     0.686651      1.334789               70.475791   0.521282
# 1480   0.746446      1.796761                0.000000   0.467060
# 1345   0.298521      1.567516                3.589553   1.428490
# 1796   0.135802      1.093827               54.826681   0.916352
#
#       ebitPerRevenue  effectiveTaxRate  enterpriseValueMultiple  \
# 1204        0.301838         -1.502471                10.346012
# 93          0.179524          0.372485                12.009523
# 1480        0.377239          0.324280                 6.480962
# 1345        0.607437          0.236663                16.805025
# 1796        0.046218          0.360000                13.906506
#
#       freeCashFlowOperatingCashFlowRatio  freeCashFlowPerShare  \
# 1204                           -0.684168             -5.979619
# 93                              0.851641              2.272082
# 1480                            0.610142              5.988624
# 1345                            0.929565              6.511458
# 1796                            0.362205              0.696970
#
#       grossProfitMargin  interestCoverage  netProfitMargin  \
# 1204           0.558719          4.601133         0.488039
# 93             0.662050          3.682353         0.086040
# 1480           0.652888         25.970679         0.218982
# 1345           0.834068          5.191013         0.392456
# 1796           0.254202          0.661654        -0.014706
#
#       operatingCashFlowPerShare  operatingCashFlowSalesRatio  \
# 1204                   8.739983                     0.529828
# 93                     2.667888                     0.252158
# 1480                   9.815135                     0.355854
# 1345                   7.004844                     0.603179
# 1796                   1.924242                     0.133403
#
#       operatingProfitMargin  payoutRatio  pretaxProfitMargin  \
# 1204               0.301838     0.013806            0.240221
# 93                 0.179524     0.601150            0.137156
# 1480               0.377239     0.627700            0.345005
# 1345               0.607437     0.000000            0.514131
# 1796               0.046218    -3.178571           -0.026261
#
#       priceEarningsToGrowthRatio  quickRatio  returnOnAssets  \
# 1204                   -0.011625    0.708103        0.051097
# 93                     -0.524049    1.233181        0.031194
# 1480                    0.552168    0.977083        0.100308
# 1345                    2.304099    1.554736        0.155464
# 1796                    0.175279    0.841975       -0.007555
#
#       returnOnCapitalEmployed
# 1204                 0.032979
# 93                   0.074649
# 1480                 0.196181
# 1345                 0.512597
# 1796                 0.026659

# %%
y_train
# Out:
# 1204    3
# 93      0
# 1480    3
# 1345    0
# 1796    0
#        ..
# 1713    2
# 624     0
# 173     0
# 1244    0
# 893     0
# Name: Rating, Length: 1620, dtype: int64

# %% [markdown]
# # **Fit Models**

# %% [markdown]
# Now we will test a range of models. In each we will fit the model in the train data, make predictons for the test data and obtain the accuracy. In later steps we will compare the accuracy of all the models. We will use primarily the library sklearn.

# %% [markdown]
# # RandomForest

# %%
RF_model = RandomForestClassifier(random_state=1234)
RF_model.fit(X_train,y_train)
y_pred_RF = RF_model.predict(X_test)
Accuracy_RF = metrics.accuracy_score(y_test, y_pred_RF)
print("RF Accuracy:",Accuracy_RF)
# Out:
# RF Accuracy: 0.6182266009852216

# %% [markdown]
# # SVC

# %%
SVC_model = svm.SVC(kernel='linear', gamma= 2, C = 5, random_state=1234)
SVC_model.fit(X_train, y_train)
y_pred_SVM = SVC_model.predict(X_test)
Accuracy_SVM = metrics.accuracy_score(y_test, y_pred_SVM)
print("SVM Accuracy:",Accuracy_SVM)
# Out:
# SVM Accuracy: 0.5098522167487685

# %% [markdown]
# # XGBRegressor

# %%
XGB_model = xgb.XGBRegressor(objective ='multi:softmax', num_class =4)
XGB_model.fit(X_train, y_train)
y_pred_XGB = XGB_model.predict(X_test)
Accuracy_XGB = metrics.accuracy_score(y_test, y_pred_XGB)
print("XGB Accuracy:",Accuracy_XGB)
# Out:
# [17:01:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softmax' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGB Accuracy: 0.645320197044335

# %%
X_test.columns.tolist()
# Out:
# ['Sector',
#  'Year',
#  'assetTurnover',
#  'cashFlowToDebtRatio',
#  'cashPerShare',
#  'cashRatio',
#  'currentRatio',
#  'daysOfSalesOutstanding',
#  'debtRatio',
#  'ebitPerRevenue',
#  'effectiveTaxRate',
#  'enterpriseValueMultiple',
#  'freeCashFlowOperatingCashFlowRatio',
#  'freeCashFlowPerShare',
#  'grossProfitMargin',
#  'interestCoverage',
#  'netProfitMargin',
#  'operatingCashFlowPerShare',
#  'operatingCashFlowSalesRatio',
#  'operatingProfitMargin',
#  'payoutRatio',
#  'pretaxProfitMargin',
#  'priceEarningsToGrowthRatio',
#  'quickRatio',
#  'returnOnAssets',
#  'returnOnCapitalEmployed']

# %%
df_test.head(3)
# Out:
#            Clean_Name                  Rating Agency Name  Sector Symbol  \
# 39              titan  Standard & Poor's Ratings Services       0    TWI
# 36              titan  Standard & Poor's Ratings Services       0    TWI
# 302  northrop grumman          Egan-Jones Ratings Company       1    NOC
#
#      Year  assetTurnover  cashFlowToDebtRatio  cashPerShare  cashRatio  \
# 39   2018       1.280640            -0.078794      1.365513   0.217787
# 36   2021       1.505232             0.021346      1.613141   0.217625
# 302  2020       0.827520             0.263367     29.365649   0.512213
#
#      currentRatio  daysOfSalesOutstanding  debtRatio  ebitPerRevenue  \
# 39       2.078239               57.625021   0.784139        0.026363
# 36       1.804083               57.337445   0.807918        0.047845
# 302      1.601670               65.870404   0.762104        0.110465
#
#      effectiveTaxRate  enterpriseValueMultiple  \
# 39           0.341394                 6.401172
# 36           0.022512                 7.574644
# 302          0.144582                10.617668
#
#      freeCashFlowOperatingCashFlowRatio  freeCashFlowPerShare  \
# 39                             2.078063             -1.256703
# 36                            -2.617565             -0.461640
# 302                            0.670151             17.265111
#
#      grossProfitMargin  interestCoverage  netProfitMargin  \
# 39            0.123730          1.387050         0.010039
# 36            0.133434          2.643462         0.027854
# 302           0.203212          6.854975         0.086660
#
#      operatingCashFlowPerShare  operatingCashFlowSalesRatio  \
# 39                   -0.604748                    -0.022576
# 36                    0.176362                     0.006025
# 302                  25.763016                     0.116987
#
#      operatingProfitMargin  payoutRatio  pretaxProfitMargin  \
# 39                0.026363     0.074657            0.012361
# 36                0.047845     0.000000            0.028671
# 302               0.110465     0.298840            0.101307
#
#      priceEarningsToGrowthRatio  quickRatio  returnOnAssets  \
# 39                     0.196238    0.892286        0.012857
# 36                     0.064805    0.837953        0.041927
# 302                    0.343861    1.205428        0.071713
#
#      returnOnCapitalEmployed  Rating
# 39                  0.048213       0
# 36                  0.116380       0
# 302                 0.116512       2

# %%
# import pickle
# pickle_out = open('/home/talentum/spark/Untitled Folder/corporateCreditRating_project/streamlit/XGB_model.pkl','wb')
# pickle.dump(XGB_model,pickle_out)
# pickle_out.close()

# %% [markdown]
# # GradientBoostingClassifier

# %%
GBT_model = GradientBoostingClassifier(random_state=123)
GBT_model.fit(X_train, y_train)
y_pred_GBT = GBT_model.predict(X_test)
Accuracy_GBT = metrics.accuracy_score(y_test, y_pred_GBT)
print("GBT Accuracy:",Accuracy_GBT)
# Out:
# GBT Accuracy: 0.6133004926108374

# %% [markdown]
# **NLPClassifier**

# %%
MLP_model = MLPClassifier(hidden_layer_sizes=(5,5,5), activation='logistic', solver='adam', max_iter=1500)
MLP_model.fit(X_train, y_train)
y_pred_MLP = MLP_model.predict(X_test)
Accuracy_MLP = metrics.accuracy_score(y_test, y_pred_MLP)
print("MLP Accuracy:",Accuracy_MLP)
# Out:
# MLP Accuracy: 0.3694581280788177

# %% [markdown]
# **GaussianNB**

# %%
GNB_model = GaussianNB()
GNB_model.fit(X_train, y_train)
y_pred_GNB = GNB_model.predict(X_test)
Accuracy_GNB = metrics.accuracy_score(y_test, y_pred_GNB)
print("GNB Accuracy:",Accuracy_GNB)
# Out:
# GNB Accuracy: 0.04926108374384237

# %% [markdown]
# **LDA**

# %%
LDA_model = LinearDiscriminantAnalysis()
LDA_model.fit(X_train,y_train)
y_pred_LDA = LDA_model.predict(X_test)
Accuracy_LDA = metrics.accuracy_score(y_test, y_pred_LDA)
print("LDA Accuracy:",Accuracy_LDA)
# Out:
# LDA Accuracy: 0.4852216748768473

# %% [markdown]
# **QDA**

# %%
QDA_model = QuadraticDiscriminantAnalysis()
QDA_model.fit(X_train,y_train)
y_pred_QDA = QDA_model.predict(X_test)
Accuracy_QDA = metrics.accuracy_score(y_test, y_pred_QDA)
print("QDA Accuracy:",Accuracy_QDA)
# Out:
# QDA Accuracy: 0.21921182266009853
# /home/talentum/.local/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:808: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %% [markdown]
# **KNN**

# %%
KNN_model = KNeighborsClassifier(n_neighbors = 3)
KNN_model.fit(X_train,y_train)
y_pred_KNN = KNN_model.predict(X_test)
Accuracy_KNN = metrics.accuracy_score(y_test, y_pred_KNN)
print("KNN Accuracy:",Accuracy_KNN)
# Out:
# KNN Accuracy: 0.4753694581280788

# %% [markdown]
# **Logistic Regression**

# %%
LR_model = LogisticRegression(random_state=1234 , multi_class='multinomial', solver='newton-cg')
LR_model = LR_model.fit(X_train, y_train)
y_pred_LR = LR_model.predict(X_test)
Accuracy_LR = metrics.accuracy_score(y_test, y_pred_LR)
print("LR Accuracy:",Accuracy_LR)
# Out:
# LR Accuracy: 0.49014778325123154
# /home/talentum/.local/lib/python3.6/site-packages/sklearn/utils/optimize.py:203: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   "number of iterations.", ConvergenceWarning)

# %% [markdown]
# ### Results

# %%
accuracy_list = [Accuracy_XGB, Accuracy_GBT, Accuracy_RF, Accuracy_SVM, Accuracy_MLP, Accuracy_GNB, 
                 Accuracy_LDA, Accuracy_QDA, Accuracy_KNN, Accuracy_LR]

model_list = ['XGBboost', 'Gradient Boosting', 'Random Forest', 'Support Vector Machine', 
              "Neural Network", 'Naive Bayes', 'Linear Discriminat', 'Quadratic Discriminat', 
              'KNN', 'Logistic Regression']

df_accuracy = pd.DataFrame({'Model': model_list, 'Accuracy': accuracy_list})

# %%
order = list(df_accuracy.sort_values('Accuracy', ascending=False).Model)
df_accuracy = df_accuracy.sort_values('Accuracy', ascending=False).reset_index().drop(['index'], axis=1)

plt.figure(figsize=(12,8))
# make barplot and sort bars
x = sns.barplot(x='Model', y="Accuracy", data=df_accuracy, order = order, palette="rocket")
plt.xlabel("Model", fontsize=20)
plt.ylabel("Accuracy", fontsize=20)
plt.title("Accuracy by Model", fontsize=20)
plt.grid(linestyle='-', linewidth='0.5', color='grey')
plt.xticks(rotation=70, fontsize=12)
plt.ylim(0,1)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

for i in range(len(model_list)):
    plt.text(x = i, y = df_accuracy.loc[i, 'Accuracy'] + 0.05, 
             s = str((str((df_accuracy.loc[i, 'Accuracy'])*100)).split('.')[0])+'%', 
             fontsize = 14, color='black',horizontalalignment='center')



plt.tight_layout()

# %% [markdown]
#  XGboost is the best performing model.

# %% [markdown]
# # XGBoost Hyperparameter Tunning

# %% [markdown]
# The XGboost model has achieved a very high accuracy given that we have 4 different classes. Now we will try to increase the performance even more. We will use a cross-validation approach and we will follow similar steps to this tutorial. First we load the train and test data into DMatrices. DMatrix is a data structure used by XGBoost to optimize both memory efficiency and training speed.

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %% [markdown]
# **The params dictionary**
#
# We create a dictonary with the parameters from our previous XGboost model.

# %%
params = XGB_model.get_xgb_params()

# %%
params['eval_metric'] = "merror"
num_boost_round = 1000
params['max_depth'] = 13
params['min_child_weight'] = 7

# %% [markdown]
# The num_boost_round which corresponds to the maximum number of boosting rounds that we allow.

# %% [markdown]
# **Results**
#
# This are the final parameters of our tunned model.

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=1000,
    verbose_eval=100
)
# Out:
# [0]	Test-merror:0.45320
# [100]	Test-merror:0.35961
# [200]	Test-merror:0.37438
# [300]	Test-merror:0.36946
# [400]	Test-merror:0.37192
# [500]	Test-merror:0.36453
# [600]	Test-merror:0.36207
# [700]	Test-merror:0.35714
# [800]	Test-merror:0.35714
# [900]	Test-merror:0.36207
# [999]	Test-merror:0.36207

# %%
num_boost_round = model.best_iteration + 1
best_model = xgb.train(
    params,
    dtrain,
    verbose_eval=100,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")]
)
# Out:
# [0]	Test-merror:0.45320
# [57]	Test-merror:0.34729

# %%
metrics.accuracy_score(best_model.predict(dtest), y_test)
# Out:
# 0.6527093596059114

# %% [markdown]
# We did not arrive in an enhanced model with this tunning. Anyone is welcome to continue this tunning and achieve a superior accuracy.

# %% [markdown]
# **Confusion Matrix**

# %% [markdown]
# We will now analyse according to each class the performance of the model. The best way to do it is with a confusion matrix. We can see how many points were missclassified and where were then classified to if not the right rating.

# %%
cm = confusion_matrix(y_test, y_pred_XGB)

# %%
fig, ax = plt.subplots(figsize=(8,8))

sns.heatmap(cm, annot = True, ax = ax, vmin=0, vmax=150, fmt="d", linewidths=.5, linecolor = 'white', cmap="Reds") # annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Medium Risk','Highest Risk', 'Low Risk', 'High Risk'])
ax.yaxis.set_ticklabels(['Medium Risk','Highest Risk', 'Low Risk', 'High Risk']);

# This part is to correct a bug from the heatmap funciton from pyplot
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

plt.show()

# %% [markdown]
# **Analysis**
#
# Given the fact that the dataset is very unbalanced, with have achieved a very low accuracy (actually 0) for very risky companies. To deal with it we wiould have to apply upsampling techniques which we may in a future work. Now we analyse other metrics as Precision, recall and F1 from our targets.

# %%
print(classification_report(y_test, y_pred_XGB, target_names = ['Medium Risk','Highest Risk', 'Low Risk', 'High Risk']))
# Out:
#               precision    recall  f1-score   support
#
#  Medium Risk       0.70      0.75      0.73       150
# Highest Risk       0.00      0.00      0.00        17
#     Low Risk       0.63      0.66      0.65        95
#    High Risk       0.60      0.60      0.60       144
#
#     accuracy                           0.65       406
#    macro avg       0.48      0.50      0.49       406
# weighted avg       0.62      0.65      0.63       406

# %%
sort(XGB_model.feature_importances_)*100

# %% [markdown]
# Apparetly the fact that we have more labels in the edium Risk has enhanced its classification. However, overall we have achieved good classification scaores for most, with the exception of Highest Risk.

# %% [markdown]
# # Feature Selection

# %% [markdown]
# In our tast task we will identify which features were the most valuable for our model. In our first step we will check if by any chance we can increase the accuracy of our model extracting a feature.

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()


warnings.simplefilter("ignore", UserWarning)

# %%
thresholds = sort(XGB_model.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(XGB_model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_train)
    # train model
    selection_model = XGBClassifier()
    selection_model.fit(select_X_train, y_train)
    # eval model
    select_X_test = selection.transform(X_test)
    y_pred = selection_model.predict(select_X_test)
    predictions = [int((str(value)).split('.')[0]) for value in y_pred]  #round(value)
    accuracy = accuracy_score(y_test, predictions)
    print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))
# Out:
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:13:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Thresh=0.000, n=26, Accuracy: 64.53%
# [17:13:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.027, n=25, Accuracy: 64.53%
# [17:13:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.031, n=24, Accuracy: 64.04%
# [17:13:57] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.031, n=23, Accuracy: 64.78%
# [17:14:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.031, n=22, Accuracy: 62.56%
# [17:14:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.032, n=21, Accuracy: 63.79%
# [17:14:05] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.032, n=20, Accuracy: 64.04%
# [17:14:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.032, n=19, Accuracy: 60.59%
# [17:14:10] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.032, n=18, Accuracy: 63.05%
# [17:14:13] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.033, n=17, Accuracy: 62.32%
# [17:14:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.033, n=16, Accuracy: 61.58%
# [17:14:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.034, n=15, Accuracy: 61.82%
# [17:14:19] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.034, n=14, Accuracy: 61.33%
# [17:14:21] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.034, n=13, Accuracy: 64.29%
# [17:14:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.037, n=12, Accuracy: 62.07%
# [17:14:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.038, n=11, Accuracy: 59.11%
# [17:14:28] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.039, n=10, Accuracy: 60.10%
# [17:14:30] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.040, n=9, Accuracy: 56.16%
# [17:14:32] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.040, n=8, Accuracy: 54.68%
# [17:14:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.040, n=7, Accuracy: 54.43%
# [17:14:35] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.041, n=6, Accuracy: 55.42%
# [17:14:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.042, n=5, Accuracy: 55.17%
# [17:14:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.042, n=4, Accuracy: 50.25%
# [17:14:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.045, n=3, Accuracy: 50.99%
# [17:14:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.069, n=2, Accuracy: 46.55%
# [17:14:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/talentum/.local/lib/python3.6/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Thresh=0.111, n=1, Accuracy: 42.61%

# %% [markdown]
# It is not the case. Now lets visualize which are the most relevant features.

# %%
from xgboost import plot_importance

fig, ax = plt.subplots(figsize=(16, 8))
#xgboost.plot_importance(..., ax=ax)

plot_importance(model, ax=ax)
plt.show()

# %% [markdown]
# # Visualize Companies

# %% [markdown]
# **Create a function to generate text for the word cloud**

# %%
def WCloud(dataframe, column, rating):
    
    words = ''
    
    # iterate through the csv file 
    for val in dataframe.loc[dataframe['Rating'] == rating, column]:
      
        # typecaste each val to string 
        val = str(val)
        val = val.replace(".", "")
        val = val.replace(",", "")

        # split the value 
        tokens = val.split()

        #Converts each token into lowercase 
        for i in range(len(tokens)): 
            tokens[i] = tokens[i].lower() 

        words += " ".join(tokens) + " "
        
    return words

# %% [markdown]
# The names of companies usually have different suffixes that are not interesting for us, such as "LLC", "plc", "holding" etc. Therefore we will consider it as stopwords.

# %%
stop_words = ['global', 'incorporated', 'corporation', ' corp', 'industries', 'technologies', 'co', 'inc', 'limited', 'ltd', 'technology', 'resources', 'corp', 'group', 'communications',
             'holdings',' holding', 'plc', 'group', 'oil', 'resource', 'company','international', 'states', 'ag', ' sa', 'pty', 'international', 'united', 'states', 'partners', 'group', 
             'spa', 'se', 'lp', '(the)', 'the', 'LLC', 'n.v', 'service', 'products', 'companies', 'company', 'energy','corporation', 'holdings', 'company', 'limited',
             'holding', 'partners', 'industries', 'nv', 'semiconductor', 'rr', 'usa', 'homes', 'eletric', 'petroleum']

# %% [markdown]
# We generate the texts and create remove stopwords

# %%
comment_wordsHR = WCloud(df_rating, 'Clean_Name', 0)
clean_text = [word for word in comment_wordsHR.split() if word not in stop_words]
comment_wordsHR = ' '.join([str(elem) for elem in clean_text])

comment_wordsHRest = WCloud(df_rating, 'Clean_Name', 1)
clean_text = [word for word in comment_wordsHRest.split() if word not in stop_words]
comment_wordsHRest = ' '.join([str(elem) for elem in clean_text])

comment_wordsLR = WCloud(df_rating, 'Clean_Name', 2)
clean_text = [word for word in comment_wordsLR.split() if word not in stop_words]
comment_wordsLR = ' '.join([str(elem) for elem in clean_text])

comment_wordsMR = WCloud(df_rating, 'Clean_Name', 3)
clean_text = [word for word in comment_wordsMR.split() if word not in stop_words]
comment_wordsMR = ' '.join([str(elem) for elem in clean_text])

# %%
wordcloudMR = WordCloud(background_color ='white', colormap="twilight", max_font_size = 25,
                min_font_size = 10).generate(comment_wordsHR) 

wordcloudLR = WordCloud(background_color ='white', colormap="twilight", max_font_size = 25,
                min_font_size = 10).generate(comment_wordsLR) 

wordcloudHR = WordCloud(background_color ='white',  colormap="ocean",max_font_size = 25,
                min_font_size = 10).generate(comment_wordsHR) 

wordcloudHRest = WordCloud(background_color ='white', colormap="gnuplot2",max_font_size = 25,
                min_font_size = 10).generate(comment_wordsHRest)

# %%
fig = plt.figure(figsize = (17,10))
axes = fig.subplots(nrows=2, ncols=2)

plt.subplot(2, 2, 1)
plt.imshow(wordcloudMR, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0)
plt.title('Medium Risk Companies', fontsize = 27)

plt.subplot(2, 2, 2)
plt.imshow(wordcloudLR, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0)
plt.title('Low Risk Companies', fontsize = 27)

plt.subplot(2, 2, 3)
plt.imshow(wordcloudHR, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0)
plt.title('High Risk Companies', fontsize = 27)

plt.subplot(2, 2, 4)
plt.imshow(wordcloudHRest, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0)
plt.title('Highest Risk Companies', fontsize = 27, fontweight = 2)
plt.show()

# %% [markdown]
# You may observe that some companies may be in different plots. Thats because they have been rated in different times with different rates
